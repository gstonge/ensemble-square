# %%
import pandas as pd
import numpy as np
import datetime
from scorepi import *
from epiweeks import Week
import matplotlib.pyplot as plt
from collections import defaultdict
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# all models
allmodels = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

allrds = [4, 5, 6, 7, 9, 10, 11, 12, 13, 14, 15, 16]

# %%
locations = pd.read_csv('./dat/locations.csv',dtype={'location':str})

# %%
# max 12 weeks ahead?

# %%
from pathlib import Path

# %%
rd = 4
start_week = Week(2021,12)
end_week = Week(2021,38)
max_date = datetime.datetime(2021, 6, 23)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd4 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd4 = pd.concat([predictions_rd4, predictions])

# %%
rd = 5
start_week = Week(2021,17)
end_week = Week(2021,43)
max_date = datetime.datetime(2021, 6, 23)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd5 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd5 = pd.concat([predictions_rd5, predictions])

# %%
rd = 6
start_week = Week(2021,21)
end_week = Week(2021,47)
max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd6 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd6 = pd.concat([predictions_rd6, predictions])

# %%
rd = 7
start_week = Week(2021,27)
end_week = Week(2021,52)
max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd7 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd7 = pd.concat([predictions_rd7, predictions])

# %%
rd = 9
start_week = Week(2021,36)
end_week = Week(2022,9)
max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd9 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd9 = pd.concat([predictions_rd9, predictions])

# %%
rd = 10
start_week = Week(2021,46)
end_week = Week(2022, 45)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd10 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd10 = pd.concat([predictions_rd10, predictions])

# %%
rd = 11
start_week = Week(2021,51)
end_week = Week(2022, 10)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd11 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd11 = pd.concat([predictions_rd11, predictions])

# %%
rd = 12
start_week = Week(2022,2)
end_week = Week(2022, 13)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd12 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd12 = pd.concat([predictions_rd12, predictions])

# %%
rd = 13
start_week = Week(2022,11)
end_week = Week(2023, 11)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd13 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd13 = pd.concat([predictions_rd13, predictions])

# %%
rd = 14
start_week = Week(2022,23)
end_week = Week(2023, 23)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd14 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd14 = pd.concat([predictions_rd14, predictions])

# %%
rd = 15
start_week = Week(2022,31)
end_week = Week(2023, 18)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd15 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd15 = pd.concat([predictions_rd15, predictions])

# %%
rd = 16
start_week = Week(2022,44)
end_week = Week(2023, 17)
#max_date = datetime.datetime(2021, 12, 21)
models = ["Ensemble","Ensemble_LOP","Ensemble_LOP_untrimmed"]

predictions_rd16 = pd.DataFrame()
for model in models:
    fil = Path(f'./dat/{model}_rd{rd}.pq')
    if fil.is_file():
    
        predictions = pd.read_parquet(f'./dat/{model}_rd{rd}.pq')

        predictions['Model'] = model
    
        predictions_rd16 = pd.concat([predictions_rd16, predictions])

# %%
predictions_rd16
# Out:
#          scenario_id   scenario_name               target target_end_date  \
# 0       A-2022-10-29  highBoo_modVar  1 wk ahead cum case      2022-11-05
# 1       A-2022-10-29  highBoo_modVar  1 wk ahead cum case      2022-11-05
# 2       A-2022-10-29  highBoo_modVar  1 wk ahead cum case      2022-11-05
# 3       A-2022-10-29  highBoo_modVar  1 wk ahead cum case      2022-11-05
# 4       A-2022-10-29  highBoo_modVar  1 wk ahead cum case      2022-11-05
# ...              ...             ...                  ...             ...
# 818059  D-2022-10-29  lowBoo_highVar  9 wk ahead inc hosp      2022-12-31
# 818060  D-2022-10-29  lowBoo_highVar  9 wk ahead inc hosp      2022-12-31
# 818061  D-2022-10-29  lowBoo_highVar  9 wk ahead inc hosp      2022-12-31
# 818062  D-2022-10-29  lowBoo_highVar  9 wk ahead inc hosp      2022-12-31
# 818063  D-2022-10-29  lowBoo_highVar  9 wk ahead inc hosp      2022-12-31
#
#        location         value      type  quantile model_projection_date  \
# 0            01  1.536303e+06  quantile     0.010            2022-10-30
# 1            02  3.003809e+05  quantile     0.010            2022-10-30
# 2            04  2.292100e+06  quantile     0.010            2022-10-30
# 3            05  9.604527e+05  quantile     0.010            2022-10-30
# 4            06  1.138180e+07  quantile     0.010            2022-10-30
# ...         ...           ...       ...       ...                   ...
# 818059       78  1.900000e+00  quantile     0.850            2022-10-30
# 818060       78  2.200000e+00  quantile     0.900            2022-10-30
# 818061       78  2.400000e+00  quantile     0.950            2022-10-30
# 818062       78  2.500000e+00  quantile     0.975            2022-10-30
# 818063       78  2.600000e+00  quantile     0.990            2022-10-30
#
#                          Model
# 0                     Ensemble
# 1                     Ensemble
# 2                     Ensemble
# 3                     Ensemble
# 4                     Ensemble
# ...                        ...
# 818059  Ensemble_LOP_untrimmed
# 818060  Ensemble_LOP_untrimmed
# 818061  Ensemble_LOP_untrimmed
# 818062  Ensemble_LOP_untrimmed
# 818063  Ensemble_LOP_untrimmed
#
# [2454192 rows x 10 columns]
